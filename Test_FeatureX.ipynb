# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
import xgboost as xgb
import lightgbm as lgb


from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
)

# %%
def build_advanced_nn(input_shape):
    model = models.Sequential()
    model.add(layers.Dense(128, activation="relu", input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))

    model.add(layers.Dense(64, activation="relu"))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))

    model.add(layers.Dense(32, activation="relu"))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))

    model.add(layers.Dense(1, activation="sigmoid"))

    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return model

# %%
train_metadata_path = (
    "E:/W/ML NUST/(T5) CNN, RNN, LSTM/isic-2024-data/train-metadata.csv"
)
test_metadata_path = "E:/W/ML NUST/(T5) CNN, RNN, LSTM/isic-2024-data/test-metadata.csv"

train_metadata = pd.read_csv(train_metadata_path)
test_metadata = pd.read_csv(test_metadata_path)

train_metadata.head()
# Out:
# C:\Users\jahme\AppData\Local\Temp\ipykernel_8236\2596913570.py:6: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_metadata = pd.read_csv(train_metadata_path)
#         isic_id  target  patient_id  age_approx   sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0  male           head/neck
# 2  ISIC_0015864       0  IP_6724798        60.0  male     posterior torso
# 3  ISIC_0015902       0  IP_4111386        65.0  male      anterior torso
# 4  ISIC_0024200       0  IP_8313778        55.0  male      anterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  ...  \
# 0                    3.04  TBP tile: close-up     3D: white  20.244422  ...
# 1                    1.10  TBP tile: close-up     3D: white  31.712570  ...
# 2                    3.40  TBP tile: close-up        3D: XP  22.575830  ...
# 3                    3.22  TBP tile: close-up        3D: XP  14.242329  ...
# 4                    2.73  TBP tile: close-up     3D: white  24.725520  ...
#
#     lesion_id  iddx_full  iddx_1  iddx_2  iddx_3  iddx_4  iddx_5  \
# 0         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 1  IL_6727506     Benign  Benign     NaN     NaN     NaN     NaN
# 2         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 3         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 4         NaN     Benign  Benign     NaN     NaN     NaN     NaN
#
#    mel_mitotic_index  mel_thick_mm  tbp_lv_dnn_lesion_confidence
# 0                NaN           NaN                     97.517282
# 1                NaN           NaN                      3.141455
# 2                NaN           NaN                     99.804040
# 3                NaN           NaN                     99.989998
# 4                NaN           NaN                     70.442510
#
# [5 rows x 55 columns]

# %%
# Checking for cols. with missing values.
missing_values = train_metadata.isnull().sum()
print("Missing Values=\n", missing_values)
# Out:
# Missing Values=
#  isic_id                              0
# target                               0
# patient_id                           0
# age_approx                        2798
# sex                              11517
# anatom_site_general               5756
# clin_size_long_diam_mm               0
# image_type                           0
# tbp_tile_type                        0
# tbp_lv_A                             0
# tbp_lv_Aext                          0
# tbp_lv_B                             0
# tbp_lv_Bext                          0
# tbp_lv_C                             0
# tbp_lv_Cext                          0
# tbp_lv_H                             0
# tbp_lv_Hext                          0
# tbp_lv_L                             0
# tbp_lv_Lext                          0
# tbp_lv_areaMM2                       0
# tbp_lv_area_perim_ratio              0
# tbp_lv_color_std_mean                0
# tbp_lv_deltaA                        0
# tbp_lv_deltaB                        0
# tbp_lv_deltaL                        0
# tbp_lv_deltaLB                       0
# tbp_lv_deltaLBnorm                   0
# tbp_lv_eccentricity                  0
# tbp_lv_location                      0
# tbp_lv_location_simple               0
# tbp_lv_minorAxisMM                   0
# tbp_lv_nevi_confidence               0
# tbp_lv_norm_border                   0
# tbp_lv_norm_color                    0
# tbp_lv_perimeterMM                   0
# tbp_lv_radial_color_std_max          0
# tbp_lv_stdL                          0
# tbp_lv_stdLExt                       0
# tbp_lv_symm_2axis                    0
# tbp_lv_symm_2axis_angle              0
# tbp_lv_x                             0
# tbp_lv_y                             0
# tbp_lv_z                             0
# attribution                          0
# copyright_license                    0
# lesion_id                       379001
# iddx_full                            0
# iddx_1                               0
# iddx_2                          399991
# iddx_3                          399994
# iddx_4                          400508
# iddx_5                          401058
# mel_mitotic_index               401006
# mel_thick_mm                    400996
# tbp_lv_dnn_lesion_confidence         0
# dtype: int64

# %%
columns_to_remove = [
    "lesion_id",
    "iddx_2",
    "iddx_3",
    "iddx_4",
    "iddx_5",
    "mel_mitotic_index",
    "mel_thick_mm",
]
train_metadata_cleaned = train_metadata.drop(columns=columns_to_remove, errors="ignore")
train_metadata_cleaned_no_nulls = train_metadata_cleaned.dropna()
train_metadata_cleaned_no_nulls["target"].value_counts()
# Out:
# target
# 0    381533
# 1       381
# Name: count, dtype: int64

# %%
majority = train_metadata_cleaned_no_nulls[
    train_metadata_cleaned_no_nulls["target"] == 0
]
minority = train_metadata_cleaned_no_nulls[
    train_metadata_cleaned_no_nulls["target"] == 1
]
majority_class_downsample = resample(
    majority, replace=False, n_samples=len(minority), random_state=42
)
train_metadata_balanced = pd.concat([majority_class_downsample, minority])


print("Shpareee after balancing classes: ", train_metadata_balanced.shape)
print(
    "Class Dist. after balancing: \n", train_metadata_balanced["target"].value_counts()
)
# Out:
# Shpareee after balancing classes:  (762, 48)
# Class Dist. after balancing:
#  target
# 0    381
# 1    381
# Name: count, dtype: int64

# %%
train_metadata_balanced["sex"] = train_metadata_balanced["sex"].map(
    {"male": 1, "female": 0}
)

anatom_site_mapping = {
    "posterior torso": 1,
    "lower extremity": 2,
    "anterior torso": 3,
    "upper extremity": 4,
    "head/neck": 5,
}

tbp_lv_location_mapping = {
    "Torso Front Top Half": 1,
    "Torso Back Top Third": 2,
    "Head & Neck": 3,
    "Torso Back Middle Third": 4,
    "Left Leg - Lower": 5,
    "Right Leg - Lower": 6,
    "Torso Front Bottom Half": 7,
    "Left Arm - Upper": 8,
    "Left Leg - Upper": 9,
    "Right Arm - Upper": 10,
    "Right Leg - Upper": 11,
    "Left Arm - Lower": 12,
    "Right Arm - Lower": 13,
    "Torso Back Bottom Third": 14,
    "Left Leg": 15,
    "Right Leg": 16,
    "Left Arm": 17,
    "Right Arm": 18,
}


tbp_lv_location_simple_mapping = {
    "Torso Back": 1,
    "Torso Front": 2,
    "Left Leg": 3,
    "Head & Neck": 4,
    "Right Leg": 5,
    "Left Arm": 6,
    "Right Arm": 7,
}


train_metadata_balanced["anatom_site_general"] = train_metadata_balanced[
    "anatom_site_general"
].apply(lambda x: anatom_site_mapping.get(x, 0))

train_metadata_balanced["tbp_lv_location"] = train_metadata_balanced[
    "tbp_lv_location"
].apply(lambda x: tbp_lv_location_mapping.get(x, 0))

train_metadata_balanced["tbp_lv_location_simple"] = train_metadata_balanced[
    "tbp_lv_location_simple"
].apply(lambda x: tbp_lv_location_simple_mapping.get(x, 0))

# %%
train_metadata_balanced.head()
# Out:
#              isic_id  target  patient_id  age_approx  sex  \
# 44730   ISIC_1176500       0  IP_4013104        50.0    0
# 362429  ISIC_9047349       0  IP_9057861        80.0    1
# 17389   ISIC_0500366       0  IP_6894380        45.0    0
# 367815  ISIC_9176171       0  IP_6422845        70.0    1
# 192982  ISIC_4857877       0  IP_7331742        65.0    1
#
#         anatom_site_general  clin_size_long_diam_mm          image_type  \
# 44730                     1                    3.35  TBP tile: close-up
# 362429                    2                    2.82  TBP tile: close-up
# 17389                     1                    4.81  TBP tile: close-up
# 367815                    1                    4.19  TBP tile: close-up
# 192982                    2                    2.52  TBP tile: close-up
#
#        tbp_tile_type   tbp_lv_A  ...  tbp_lv_symm_2axis  \
# 44730      3D: white  21.195278  ...           0.726667
# 362429     3D: white  17.323980  ...           0.460432
# 17389      3D: white  19.021500  ...           0.207865
# 367815     3D: white  19.501620  ...           0.334615
# 192982        3D: XP  21.714430  ...           0.185185
#
#         tbp_lv_symm_2axis_angle    tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 44730                        60 -103.079308  1195.573975  227.486694
# 362429                      110 -170.181000   764.250000   29.220830
# 17389                        15   66.219480  1457.846000   78.279170
# 367815                       55  -39.389570  1057.866000  169.172800
# 192982                       55 -150.631100   749.153000   -3.548462
#
#                                               attribution  copyright_license  \
# 44730              Memorial Sloan Kettering Cancer Center              CC-BY
# 362429             Memorial Sloan Kettering Cancer Center              CC-BY
# 17389              Memorial Sloan Kettering Cancer Center              CC-BY
# 367815             Memorial Sloan Kettering Cancer Center              CC-BY
# 192982  Department of Dermatology, Hospital Clínic de ...           CC-BY-NC
#
#         iddx_full  iddx_1  tbp_lv_dnn_lesion_confidence
# 44730      Benign  Benign                     99.990058
# 362429     Benign  Benign                     99.999270
# 17389      Benign  Benign                     99.999990
# 367815     Benign  Benign                     99.997030
# 192982     Benign  Benign                     99.999950
#
# [5 rows x 48 columns]

# %%
train_metadata_balanced["age_sex_interaction"] = (
    train_metadata_balanced["age_approx"] * train_metadata_balanced["sex"]
)

# %%
X = train_metadata_balanced.drop(
    columns=[
        "isic_id",
        "target",
        "patient_id",
        "image_type",
        "tbp_tile_type",
        "attribution",
        "copyright_license",
        "iddx_full",
        "iddx_1",
        "tbp_lv_dnn_lesion_confidence",
    ]
)
y = train_metadata_balanced["target"]

# %%
X.head()
# Out:
#         age_approx  sex  anatom_site_general  clin_size_long_diam_mm  \
# 44730         50.0    0                    1                    3.35
# 362429        80.0    1                    2                    2.82
# 17389         45.0    0                    1                    4.81
# 367815        70.0    1                    1                    4.19
# 192982        65.0    1                    2                    2.52
#
#          tbp_lv_A  tbp_lv_Aext   tbp_lv_B  tbp_lv_Bext   tbp_lv_C  \
# 44730   21.195278    17.154688  31.151941    27.220952  37.678684
# 362429  17.323980    13.713120  27.650850    24.298250  32.629590
# 17389   19.021500    13.692660  25.292780    24.429680  31.647150
# 367815  19.501620    15.038260  28.079500    25.470960  34.187300
# 192982  21.714430    15.247080  31.490850    29.277120  38.251660
#
#         tbp_lv_Cext  ...  tbp_lv_perimeterMM  tbp_lv_radial_color_std_max  \
# 44730     32.175511  ...           10.469371                     0.000000
# 362429    27.900800  ...            9.113276                     0.382295
# 17389     28.005320  ...           14.471180                     1.077988
# 367815    29.579030  ...           12.987830                     0.922462
# 192982    33.009440  ...            7.355957                     1.260871
#
#         tbp_lv_stdL  tbp_lv_stdLExt  tbp_lv_symm_2axis  \
# 44730      1.015532        2.300134           0.726667
# 362429     2.097523        1.949897           0.460432
# 17389      3.546986        2.971106           0.207865
# 367815     1.989967        2.103671           0.334615
# 192982     3.497889        1.895894           0.185185
#
#         tbp_lv_symm_2axis_angle    tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 44730                        60 -103.079308  1195.573975  227.486694
# 362429                      110 -170.181000   764.250000   29.220830
# 17389                        15   66.219480  1457.846000   78.279170
# 367815                       55  -39.389570  1057.866000  169.172800
# 192982                       55 -150.631100   749.153000   -3.548462
#
#         age_sex_interaction
# 44730                   0.0
# 362429                 80.0
# 17389                   0.0
# 367815                 70.0
# 192982                 65.0
#
# [5 rows x 39 columns]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
train_dataset = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .batch(64)
    .shuffle(buffer_size=1024)
)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(64)

# %%
print(X_train.shape)
# Out:
# (609, 39)

# %%
input_shape = (X_train.shape[1],)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=3
)
model = build_advanced_nn(input_shape)
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=[early_stopping, reduce_lr],
)
# Out:
# Epoch 1/50
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5685 - loss: 0.8145 - val_accuracy: 0.6601 - val_loss: 0.6569 - learning_rate: 0.0010
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6060 - loss: 0.7263 - val_accuracy: 0.7059 - val_loss: 0.6100 - learning_rate: 0.0010
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6736 - loss: 0.6460 - val_accuracy: 0.7451 - val_loss: 0.5764 - learning_rate: 0.0010
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7011 - loss: 0.6188 - val_accuracy: 0.7582 - val_loss: 0.5553 - learning_rate: 0.0010
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7610 - loss: 0.5559 - val_accuracy: 0.7582 - val_loss: 0.5375 - learning_rate: 0.0010
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7466 - loss: 0.5494 - val_accuracy: 0.7843 - val_loss: 0.5231 - learning_rate: 0.0010
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7589 - loss: 0.4800 - val_accuracy: 0.7843 - val_loss: 0.5132 - learning_rate: 0.0010
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7871 - loss: 0.4677 - val_accuracy: 0.7974 - val_loss: 0.5037 - learning_rate: 0.0010
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7897 - loss: 0.4775 - val_accuracy: 0.7974 - val_loss: 0.4938 - learning_rate: 0.0010
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7765 - loss: 0.4619 - val_accuracy: 0.7778 - val_loss: 0.4867 - learning_rate: 0.0010
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8138 - loss: 0.4450 - val_accuracy: 0.7843 - val_loss: 0.4789 - learning_rate: 0.0010
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8428 - loss: 0.4167 - val_accuracy: 0.8039 - val_loss: 0.4707 - learning_rate: 0.0010
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8440 - loss: 0.4103 - val_accuracy: 0.8105 - val_loss: 0.4638 - learning_rate: 0.0010
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8433 - loss: 0.3707 - val_accuracy: 0.8235 - val_loss: 0.4591 - learning_rate: 0.0010
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8245 - loss: 0.4185 - val_accuracy: 0.8039 - val_loss: 0.4551 - learning_rate: 0.0010
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8564 - loss: 0.3774 - val_accuracy: 0.7974 - val_loss: 0.4536 - learning_rate: 0.0010
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8468 - loss: 0.3964 - val_accuracy: 0.7974 - val_loss: 0.4530 - learning_rate: 0.0010
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8457 - loss: 0.3805 - val_accuracy: 0.7908 - val_loss: 0.4493 - learning_rate: 0.0010
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8657 - loss: 0.3138 - val_accuracy: 0.8039 - val_loss: 0.4488 - learning_rate: 0.0010
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8302 - loss: 0.4083 - val_accuracy: 0.8039 - val_loss: 0.4475 - learning_rate: 0.0010
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8201 - loss: 0.4146 - val_accuracy: 0.7908 - val_loss: 0.4478 - learning_rate: 0.0010
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8327 - loss: 0.3363 - val_accuracy: 0.7908 - val_loss: 0.4470 - learning_rate: 0.0010
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8377 - loss: 0.3775 - val_accuracy: 0.7843 - val_loss: 0.4512 - learning_rate: 0.0010
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8767 - loss: 0.3176 - val_accuracy: 0.7908 - val_loss: 0.4552 - learning_rate: 0.0010
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8684 - loss: 0.3414 - val_accuracy: 0.7843 - val_loss: 0.4589 - learning_rate: 0.0010
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8726 - loss: 0.3599 - val_accuracy: 0.7843 - val_loss: 0.4595 - learning_rate: 5.0000e-04
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8534 - loss: 0.3889 - val_accuracy: 0.7843 - val_loss: 0.4584 - learning_rate: 5.0000e-04

# %%
val_loss, val_accuracy = model.evaluate(val_dataset)
print(f"Validation Accuracy: {val_accuracy:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7919 - loss: 0.4316
# Validation Accuracy: 0.7908

# %%
xgb_model = xgb.XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    objective="binary:logistic",
    eval_metric="auc",
)
xgb_model.fit(X_train, y_train)
y_val_pred_xgb = xgb_model.predict_proba(X_val)[:, 1]
roc_auc_xgb = roc_auc_score(y_val, y_val_pred_xgb)
print(f"XGBoost ROC AUC Score: {roc_auc_xgb:.4f}")
# Out:
# XGBoost ROC AUC Score: 0.9191

# %%
test_metadata_cleaned = test_metadata.drop(columns=columns_to_remove, errors="ignore")
test_metadata_cleaned["sex"] = test_metadata_cleaned["sex"].map(
    {"male": 1, "female": 0}
)
test_metadata_cleaned["anatom_site_general"] = test_metadata_cleaned[
    "anatom_site_general"
].apply(lambda x: anatom_site_mapping.get(x, 0))
test_metadata_cleaned["tbp_lv_location"] = test_metadata_cleaned[
    "tbp_lv_location"
].apply(lambda x: tbp_lv_location_mapping.get(x, 0))
test_metadata_cleaned["tbp_lv_location_simple"] = test_metadata_cleaned[
    "tbp_lv_location_simple"
].apply(lambda x: tbp_lv_location_simple_mapping.get(x, 0))

test_metadata_cleaned["age_sex_interaction"] = (
    test_metadata_cleaned["age_approx"] * test_metadata_cleaned["sex"]
)

# %%
X_test = test_metadata_cleaned[X.columns]  # Align columns with training set
X_test_scaled = scaler.transform(X_test)
X_test.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8236\1657964405.py in ?()
#       1 X_test = test_metadata_cleaned[X.columns]  # Align columns with training set
# ----> 2 X_test_scaled = scaler.transform(X_test)
#       3 X_test.head()
#
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, copy)
#    1039         """
#    1040         check_is_fitted(self)
#    1041
#    1042         copy = copy if copy is not None else self.copy
# -> 1043         X = self._validate_data(
#    1044             X,
#    1045             reset=False,
#    1046             accept_sparse="csr",
#
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Torso Front Bottom Half'

# %%
test_metadata_cleaned.head()
# Out:
#         isic_id  patient_id  age_approx  sex  anatom_site_general  \
# 0  ISIC_0015657  IP_6074337        45.0    1                    1
# 1  ISIC_0015729  IP_1664139        35.0    0                    2
# 2  ISIC_0015740  IP_7142616        65.0    1                    1
# 3  ISIC_0287900  IP_9526638        60.0    1                    1
# 4  ISIC_0330452  IP_0199195        55.0    0                    3
#
#    clin_size_long_diam_mm          image_type tbp_tile_type  tbp_lv_A  \
# 0                    2.70  TBP tile: close-up        3D: XP  22.80433
# 1                    2.52  TBP tile: close-up        3D: XP  16.64867
# 2                    3.16  TBP tile: close-up        3D: XP  24.25384
# 3                    1.65  TBP tile: close-up     3D: white  25.83159
# 4                    7.49  TBP tile: close-up        3D: XP  18.91623
#
#    tbp_lv_Aext  ...                             tbp_lv_stdL    tbp_lv_stdLExt  \
# 0    20.007270  ...                                1.281532          2.299935
# 1     9.657964  ...                        1.27193967210918  2.01122296029061
# 2    19.937380  ...                                1.080308          2.705857
# 3    16.196630  ...                                6.484267          93.06311
# 4    12.190850  ...  Memorial Sloan Kettering Cancer Center             CC-BY
#
#                         tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle   tbp_lv_x  \
# 0                               0.4793388                       20 -155.06510
# 1                       0.426229508196721                       25 -112.36924
# 2                               0.3660714                      110  -84.29282
# 3  Memorial Sloan Kettering Cancer Center                    CC-BY        NaN
# 4                                     NaN                      NaN        NaN
#
#       tbp_lv_y    tbp_lv_z                                        attribution  \
# 0  1511.222000  113.980100             Memorial Sloan Kettering Cancer Center
# 1   629.535889  -15.019287  Frazer Institute, The University of Queensland...
# 2  1303.978000  -28.576050                                        FNQH Cairns
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
#
#    copyright_license  age_sex_interaction
# 0              CC-BY                 45.0
# 1              CC-BY                  0.0
# 2              CC-BY                 65.0
# 3                NaN                 60.0
# 4                NaN                  0.0
#
# [5 rows x 45 columns]

# %%
test_predictions = xgb_model.predict_proba(X_test_scaled)[:, 1]
test_predicted_labels = (test_predictions > 0.5).astype(int)

# %%
submission = pd.DataFrame(
    {"isic_id": test_metadata["isic_id"], "target": test_predicted_labels}
)
submission.to_csv(
    "C:/Users/jahme/Desktop/Prac/Kaggle/ISIC_Skin_Cancer/output/submission.csv",
    index=False,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 submission = pd.DataFrame(
#       2     {"isic_id": test_metadata["isic_id"], "target": test_predicted_labels}
#       3 )
#       4 submission.to_csv(
#       5     "C:/Users/jahme/Desktop/Prac/Kaggle/ISIC_Skin_Cancer/output/submission.csv",
#       6     index=False,
#       7 )
#
# File c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\jahme\anaconda3\envs\PracConda\Lib\site-packages\pandas\core\internals\construction.py:690, in _extract_index(data)
#     685     if lengths[0] != len(index):
#     686         msg = (
#     687             f"array length {lengths[0]} does not match index "
#     688             f"length {len(index)}"
#     689         )
# --> 690         raise ValueError(msg)
#     691 else:
#     692     index = default_index(lengths[0])
#
# ValueError: array length 3 does not match index length 8
