# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf

from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
)

# %%
def build_dense_nn(input_shape):
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(32, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')  # Binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
train_metadata_path = (
    "E:/W/ML NUST/(T5) CNN, RNN, LSTM/isic-2024-data/train-metadata.csv"
)
test_metadata_path = "E:/W/ML NUST/(T5) CNN, RNN, LSTM/isic-2024-data/test-metadata.csv"

train_metadata = pd.read_csv(train_metadata_path)
test_metadata = pd.read_csv(test_metadata_path)

train_metadata.head()
# Out:
# C:\Users\jahme\AppData\Local\Temp\ipykernel_3684\2963458992.py:6: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_metadata = pd.read_csv(train_metadata_path)
#         isic_id  target  patient_id  age_approx   sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0  male           head/neck
# 2  ISIC_0015864       0  IP_6724798        60.0  male     posterior torso
# 3  ISIC_0015902       0  IP_4111386        65.0  male      anterior torso
# 4  ISIC_0024200       0  IP_8313778        55.0  male      anterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  ...  \
# 0                    3.04  TBP tile: close-up     3D: white  20.244422  ...
# 1                    1.10  TBP tile: close-up     3D: white  31.712570  ...
# 2                    3.40  TBP tile: close-up        3D: XP  22.575830  ...
# 3                    3.22  TBP tile: close-up        3D: XP  14.242329  ...
# 4                    2.73  TBP tile: close-up     3D: white  24.725520  ...
#
#     lesion_id  iddx_full  iddx_1  iddx_2  iddx_3  iddx_4  iddx_5  \
# 0         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 1  IL_6727506     Benign  Benign     NaN     NaN     NaN     NaN
# 2         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 3         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 4         NaN     Benign  Benign     NaN     NaN     NaN     NaN
#
#    mel_mitotic_index  mel_thick_mm  tbp_lv_dnn_lesion_confidence
# 0                NaN           NaN                     97.517282
# 1                NaN           NaN                      3.141455
# 2                NaN           NaN                     99.804040
# 3                NaN           NaN                     99.989998
# 4                NaN           NaN                     70.442510
#
# [5 rows x 55 columns]

# %%
# Checking for cols. with missing values.
missing_values = train_metadata.isnull().sum()
print("Missing Values=\n", missing_values)
# Out:
# Missing Values=
#  isic_id                              0
# target                               0
# patient_id                           0
# age_approx                        2798
# sex                              11517
# anatom_site_general               5756
# clin_size_long_diam_mm               0
# image_type                           0
# tbp_tile_type                        0
# tbp_lv_A                             0
# tbp_lv_Aext                          0
# tbp_lv_B                             0
# tbp_lv_Bext                          0
# tbp_lv_C                             0
# tbp_lv_Cext                          0
# tbp_lv_H                             0
# tbp_lv_Hext                          0
# tbp_lv_L                             0
# tbp_lv_Lext                          0
# tbp_lv_areaMM2                       0
# tbp_lv_area_perim_ratio              0
# tbp_lv_color_std_mean                0
# tbp_lv_deltaA                        0
# tbp_lv_deltaB                        0
# tbp_lv_deltaL                        0
# tbp_lv_deltaLB                       0
# tbp_lv_deltaLBnorm                   0
# tbp_lv_eccentricity                  0
# tbp_lv_location                      0
# tbp_lv_location_simple               0
# tbp_lv_minorAxisMM                   0
# tbp_lv_nevi_confidence               0
# tbp_lv_norm_border                   0
# tbp_lv_norm_color                    0
# tbp_lv_perimeterMM                   0
# tbp_lv_radial_color_std_max          0
# tbp_lv_stdL                          0
# tbp_lv_stdLExt                       0
# tbp_lv_symm_2axis                    0
# tbp_lv_symm_2axis_angle              0
# tbp_lv_x                             0
# tbp_lv_y                             0
# tbp_lv_z                             0
# attribution                          0
# copyright_license                    0
# lesion_id                       379001
# iddx_full                            0
# iddx_1                               0
# iddx_2                          399991
# iddx_3                          399994
# iddx_4                          400508
# iddx_5                          401058
# mel_mitotic_index               401006
# mel_thick_mm                    400996
# tbp_lv_dnn_lesion_confidence         0
# dtype: int64

# %%
columns_to_remove = [
    "lesion_id",
    "iddx_2",
    "iddx_3",
    "iddx_4",
    "iddx_5",
    "mel_mitotic_index",
    "mel_thick_mm",
]
train_metadata_cleaned = train_metadata.drop(columns=columns_to_remove, errors="ignore")
train_metadata_cleaned_no_nulls = train_metadata_cleaned.dropna()

# %%
train_metadata_cleaned_no_nulls["target"].value_counts()
# Out:
# target
# 0    381533
# 1       381
# Name: count, dtype: int64

# %%
majority = train_metadata_cleaned_no_nulls[
    train_metadata_cleaned_no_nulls["target"] == 0
]
minority = train_metadata_cleaned_no_nulls[
    train_metadata_cleaned_no_nulls["target"] == 1
]
majority_class_downsample = resample(
    majority, replace=False, n_samples=len(minority), random_state=42
)
train_metadata_balanced = pd.concat([majority_class_downsample, minority])


print("Shpareee after balancing classes: ", train_metadata_balanced.shape)
print(
    "Class Dist. after balancing: \n", train_metadata_balanced["target"].value_counts()
)
# Out:
# Shpareee after balancing classes:  (762, 48)
# Class Dist. after balancing:
#  target
# 0    381
# 1    381
# Name: count, dtype: int64

# %%
train_metadata_balanced.head()
# Out:
#              isic_id  target  patient_id  age_approx     sex  \
# 44730   ISIC_1176500       0  IP_4013104        50.0  female
# 362429  ISIC_9047349       0  IP_9057861        80.0    male
# 17389   ISIC_0500366       0  IP_6894380        45.0  female
# 367815  ISIC_9176171       0  IP_6422845        70.0    male
# 192982  ISIC_4857877       0  IP_7331742        65.0    male
#
#        anatom_site_general  clin_size_long_diam_mm          image_type  \
# 44730      posterior torso                    3.35  TBP tile: close-up
# 362429     lower extremity                    2.82  TBP tile: close-up
# 17389      posterior torso                    4.81  TBP tile: close-up
# 367815     posterior torso                    4.19  TBP tile: close-up
# 192982     lower extremity                    2.52  TBP tile: close-up
#
#        tbp_tile_type   tbp_lv_A  ...  tbp_lv_symm_2axis  \
# 44730      3D: white  21.195278  ...           0.726667
# 362429     3D: white  17.323980  ...           0.460432
# 17389      3D: white  19.021500  ...           0.207865
# 367815     3D: white  19.501620  ...           0.334615
# 192982        3D: XP  21.714430  ...           0.185185
#
#         tbp_lv_symm_2axis_angle    tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 44730                        60 -103.079308  1195.573975  227.486694
# 362429                      110 -170.181000   764.250000   29.220830
# 17389                        15   66.219480  1457.846000   78.279170
# 367815                       55  -39.389570  1057.866000  169.172800
# 192982                       55 -150.631100   749.153000   -3.548462
#
#                                               attribution  copyright_license  \
# 44730              Memorial Sloan Kettering Cancer Center              CC-BY
# 362429             Memorial Sloan Kettering Cancer Center              CC-BY
# 17389              Memorial Sloan Kettering Cancer Center              CC-BY
# 367815             Memorial Sloan Kettering Cancer Center              CC-BY
# 192982  Department of Dermatology, Hospital Clínic de ...           CC-BY-NC
#
#         iddx_full  iddx_1  tbp_lv_dnn_lesion_confidence
# 44730      Benign  Benign                     99.990058
# 362429     Benign  Benign                     99.999270
# 17389      Benign  Benign                     99.999990
# 367815     Benign  Benign                     99.997030
# 192982     Benign  Benign                     99.999950
#
# [5 rows x 48 columns]

# %%
train_metadata_balanced["sex"] = train_metadata_balanced["sex"].map(
    {"male": 1, "female": 0}
)

anatom_site_mapping = {
    "posterior torso": 1,
    "lower extremity": 2,
    "anterior torso": 3,
    "upper extremity": 4,
    "head/neck": 5,
}

tbp_lv_location_mapping = {
    "Torso Front Top Half": 1,
    "Torso Back Top Third": 2,
    "Head & Neck": 3,
    "Torso Back Middle Third": 4,
    "Left Leg - Lower": 5,
    "Right Leg - Lower": 6,
    "Torso Front Bottom Half": 7,
    "Left Arm - Upper": 8,
    "Left Leg - Upper": 9,
    "Right Arm - Upper": 10,
    "Right Leg - Upper": 11,
    "Left Arm - Lower": 12,
    "Right Arm - Lower": 13,
    "Torso Back Bottom Third": 14,
    "Left Leg": 15,
    "Right Leg": 16,
    "Left Arm": 17,
    "Right Arm": 18,
}


tbp_lv_location_simple_mapping = {
    "Torso Back": 1,
    "Torso Front": 2,
    "Left Leg": 3,
    "Head & Neck": 4,
    "Right Leg": 5,
    "Left Arm": 6,
    "Right Arm": 7,
}


train_metadata_balanced["anatom_site_general"] = train_metadata_balanced[
    "anatom_site_general"
].apply(lambda x: anatom_site_mapping.get(x, 0))

train_metadata_balanced["tbp_lv_location"] = train_metadata_balanced[
    "tbp_lv_location"
].apply(lambda x: tbp_lv_location_mapping.get(x, 0))

train_metadata_balanced["tbp_lv_location_simple"] = train_metadata_balanced[
    "tbp_lv_location_simple"
].apply(lambda x: tbp_lv_location_simple_mapping.get(x, 0))

# %%
X = train_metadata_balanced.drop(columns=['isic_id', 'target', 'patient_id', 'image_type', 'tbp_tile_type', 'attribution', 'copyright_license', 'iddx_full', 'iddx_1', 'tbp_lv_dnn_lesion_confidence'])
y = train_metadata_balanced['target']

# %%
scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(64).shuffle(buffer_size=1024)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(64)

# %%
print(X_train.shape)
# Out:
# (609, 38)

# %%
input_shape = (38,)
model = build_dense_nn(input_shape)
model.fit(train_dataset, validation_data=val_dataset, epochs=35)
# Out:
# Epoch 1/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5126 - loss: 1.0214 - val_accuracy: 0.6209 - val_loss: 0.6584
# Epoch 2/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5285 - loss: 0.8765 - val_accuracy: 0.7190 - val_loss: 0.6001
# Epoch 3/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6238 - loss: 0.7806 - val_accuracy: 0.7451 - val_loss: 0.5612
# Epoch 4/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.6840 - val_accuracy: 0.7516 - val_loss: 0.5354
# Epoch 5/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6980 - loss: 0.6501 - val_accuracy: 0.7386 - val_loss: 0.5163
# Epoch 6/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6963 - loss: 0.6296 - val_accuracy: 0.7582 - val_loss: 0.4978
# Epoch 7/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6841 - loss: 0.6554 - val_accuracy: 0.7647 - val_loss: 0.4851
# Epoch 8/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7269 - loss: 0.6470 - val_accuracy: 0.7712 - val_loss: 0.4756
# Epoch 9/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7218 - loss: 0.6073 - val_accuracy: 0.7778 - val_loss: 0.4692
# Epoch 10/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7705 - loss: 0.5283 - val_accuracy: 0.7843 - val_loss: 0.4635
# Epoch 11/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7663 - loss: 0.5008 - val_accuracy: 0.7908 - val_loss: 0.4588
# Epoch 12/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7569 - loss: 0.5415 - val_accuracy: 0.7843 - val_loss: 0.4545
# Epoch 13/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7457 - loss: 0.5459 - val_accuracy: 0.7908 - val_loss: 0.4526
# Epoch 14/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7668 - loss: 0.5423 - val_accuracy: 0.7778 - val_loss: 0.4511
# Epoch 15/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7839 - loss: 0.4695 - val_accuracy: 0.7778 - val_loss: 0.4484
# Epoch 16/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7856 - loss: 0.4701 - val_accuracy: 0.7712 - val_loss: 0.4479
# Epoch 17/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7847 - loss: 0.4443 - val_accuracy: 0.7712 - val_loss: 0.4466
# Epoch 18/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7534 - loss: 0.5048 - val_accuracy: 0.7712 - val_loss: 0.4456
# Epoch 19/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - loss: 0.4816 - val_accuracy: 0.7712 - val_loss: 0.4432
# Epoch 20/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7846 - loss: 0.4573 - val_accuracy: 0.7712 - val_loss: 0.4418
# Epoch 21/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7797 - loss: 0.4747 - val_accuracy: 0.7712 - val_loss: 0.4415
# Epoch 22/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7815 - loss: 0.4639 - val_accuracy: 0.7712 - val_loss: 0.4417
# Epoch 23/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8132 - loss: 0.4507 - val_accuracy: 0.7778 - val_loss: 0.4427
# Epoch 24/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7987 - loss: 0.4541 - val_accuracy: 0.7778 - val_loss: 0.4417
# Epoch 25/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7952 - loss: 0.4654 - val_accuracy: 0.7778 - val_loss: 0.4429
# Epoch 26/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7929 - loss: 0.4722 - val_accuracy: 0.7778 - val_loss: 0.4414
# Epoch 27/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8018 - loss: 0.4462 - val_accuracy: 0.7908 - val_loss: 0.4414
# Epoch 28/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8315 - loss: 0.3938 - val_accuracy: 0.7843 - val_loss: 0.4425
# Epoch 29/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7994 - loss: 0.4150 - val_accuracy: 0.7843 - val_loss: 0.4430
# Epoch 30/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7956 - loss: 0.4533 - val_accuracy: 0.7843 - val_loss: 0.4436
# Epoch 31/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8268 - loss: 0.4276 - val_accuracy: 0.7843 - val_loss: 0.4446
# Epoch 32/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8166 - loss: 0.4084 - val_accuracy: 0.7908 - val_loss: 0.4461
# Epoch 33/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8265 - loss: 0.3834 - val_accuracy: 0.7843 - val_loss: 0.4463
# Epoch 34/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8355 - loss: 0.3968 - val_accuracy: 0.7843 - val_loss: 0.4468
# Epoch 35/35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8539 - loss: 0.3882 - val_accuracy: 0.7843 - val_loss: 0.4456

# %%
val_loss, val_accuracy = model.evaluate(val_dataset)
print(f'Validation Accuracy: {val_accuracy:.4f}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7945 - loss: 0.4254
# Validation Accuracy: 0.7843

# %%
test_metadata_cleaned = test_metadata.drop(columns=columns_to_remove, errors='ignore')
test_metadata_cleaned['sex'] = test_metadata_cleaned['sex'].map({'male': 1, 'female': 0})
test_metadata_cleaned['anatom_site_general'] = test_metadata_cleaned['anatom_site_general'].apply(
    lambda x: anatom_site_mapping.get(x, 0)
)
test_metadata_cleaned['tbp_lv_location'] = test_metadata_cleaned['tbp_lv_location'].apply(
    lambda x: tbp_lv_location_mapping.get(x, 0)
)
test_metadata_cleaned['tbp_lv_location_simple'] = test_metadata_cleaned['tbp_lv_location_simple'].apply(
    lambda x: tbp_lv_location_simple_mapping.get(x, 0)
)

# %%
X_test = test_metadata_cleaned.drop(columns=['isic_id', 'patient_id', 'image_type', 'tbp_tile_type', 'attribution', 'copyright_license'])
X_test_scaled = scalar.transform(X_test)

# %%
test_predictions = model.predict(X_test_scaled)
test_predicted_labels = (test_predictions > 0.5).astype(int).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
submission = pd.DataFrame({
    'isic_id': test_metadata['isic_id'],
    'target': test_predicted_labels
})

submission.to_csv('C:/Users/jahme/Desktop/Prac/Kaggle/ISIC_Skin_Cancer/output/submission.csv', index=False)
